# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
model=KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz",binary=True,limit=500000)

# %%
model

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
len(model['cricket'])
# Out:
# 300

# %%
model.most_similar("man")
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116),
#  ('guy', 0.5420035123825073)]

# %%
model.most_similar("Vishal")
# Out:
# [('Sanjay', 0.853866696357727),
#  ('Kunal', 0.827887237071991),
#  ('Ajay', 0.8174487948417664),
#  ('Vikram', 0.8146809935569763),
#  ('Mahesh', 0.7939050793647766),
#  ('Gaurav', 0.7931963801383972),
#  ('Mohit', 0.7924777865409851),
#  ('Siddharth', 0.7917003035545349),
#  ('Abhishek', 0.7908650636672974),
#  ('Vipul', 0.7899187803268433)]

# %%
model.most_similar("Intelligence")
# Out:
# [('intelligence', 0.7189884185791016),
#  ('Intelligence_Agency', 0.564673900604248),
#  ('Military_Intelligence', 0.5455402731895447),
#  ('Counter_terrorism', 0.5225995182991028),
#  ('Intelligence_Directorate', 0.5219962000846863),
#  ('Security', 0.5096436738967896),
#  ('Intelligence_Committee', 0.4966195821762085),
#  ('Counterterror', 0.4880608320236206),
#  ('counterintelligence', 0.48536795377731323),
#  ('DNI', 0.48360371589660645)]

# %%
model.most_similar("AI")
# Out:
# [('mechs', 0.5137375593185425),
#  ('mech', 0.5077533721923828),
#  ('multiplayer', 0.5033435821533203),
#  ('gameplay', 0.5024632215499878),
#  ('multiplayer_mode', 0.49896788597106934),
#  ('artificial_intelligence', 0.494051992893219),
#  ('Multiplayer', 0.4898778796195984),
#  ('Blazing_Angels', 0.4857530891895294),
#  ('pathfinding', 0.47735223174095154),
#  ('Gameplay', 0.46820494532585144)]

# %%
model.most_similar("Data")
# Out:
# [('data', 0.7262316346168518),
#  ('Database', 0.4912521541118622),
#  ('Figures', 0.4676622450351715),
#  ('Information', 0.4570310711860657),
#  ('Databases', 0.43482157588005066),
#  ('Storage_Solution', 0.433370977640152),
#  ('Statistics', 0.42754971981048584),
#  ('Monitoring', 0.4271542429924011),
#  ('Device', 0.42560356855392456),
#  ('Performance_Metrics', 0.41793981194496155)]

# %%
model.similarity("PHP","JAVA")
# Out:
# 0.47809428

# %%
model.doesnt_match(["PHP","JAVA","DOG","C++","Python"])
# Out:
# 'DOG'

# %%
queen = model['king']-model['man']+model["woman"]

# %%
model.most_similar([queen])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('queens', 0.5289887189865112),
#  ('ruler', 0.5247419476509094)]
